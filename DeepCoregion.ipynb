# %% [markdown]
# ## Make Deep Learned Kernel with multioutput
# -Could be useful: https://github.com/vlad17/runlmc
#
# Links:
# - https://github.com/GPflow/GPflow/pull/138 - coregion kernel
# - https://github.com/GPflow/GPflow/pull/139 - coregion kernel
# - https://en.wikipedia.org/wiki/Kernel_methods_for_vector_output#Linear_model_of_coregionalization_.28LMC.29
# - http://gpflow.readthedocs.io/en/latest/notebooks/coreg_demo.html?highlight=coregion
# - https://bigaidream.gitbooks.io/subsets_ml_cookbook/content/bayes/gp/coregionalized_regression_gpy.html - Gpy might be useful

# %%
import numpy as np
import matplotlib.pyplot as plt
import gpflow
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras import backend as K
# %matplotlib inline

from modeling import Model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Generate some data

# %%
#Code from https://github.com/dfm/gprv/blob/master/demo.ipynb
#which in turn was inspired from Rajpaul et al. (2015)
class SimpleKernel(Model):
    parameter_names = ("log_b", )
    
    def get_value(self, tau):
        a = 1.0
        b = np.exp(self.log_b)
        return a * np.exp(-b * tau**2)
    
    def get_grad_1_value(self, tau):
        a = 1.0
        b = np.exp(self.log_b)
        return 2 * a * b * tau * np.exp(-b * tau**2)
    
    def get_grad_2_value(self, tau):
        a = 1.0
        b = np.exp(self.log_b)
        return 2 * a * b * np.exp(-b * tau**2) * (1.0 - 2 * b * tau**2)

class RVKernel(Model):
    parameter_names = ("vc", "vr", "lc", "bc", "br")
    
    def __init__(self, G, *args, **kwargs):
        self.G = G
        super(RVKernel, self).__init__(*args, **kwargs)
    
    def get_value(self, tau, l1, l2):
#         vc = np.exp(self.log_vc)
#         vr = np.exp(self.log_vr)
#         lc = np.exp(self.log_lc)
#         bc = np.exp(self.log_bc)
#         br = np.exp(self.log_br)
        vc = self.vc
        vr = self.vr
        lc = self.lc
        bc = self.bc
        br = self.br
        
        # Compute the value of gamma and its derivatives
        g = self.G.get_value(tau)
        gp1 = self.G.get_grad_1_value(tau)
        gp2 = self.G.get_grad_1_value(-tau)
        gpp = self.G.get_grad_2_value(tau)
        
        # We'll use these masks to build the blocked kernel matrix
        m11 = l1 == 1
        m12 = l1 == 2
        m13 = l1 == 3
        m21 = l2 == 1
        m22 = l2 == 2
        m23 = l2 == 3
        
        # Allocate the matrix and loop over blocks
        K = np.zeros_like(tau)
        zero_tau = np.isclose(tau, 0.0)
        
        # k11
        m = m11 * m21
        K[m] = vc**2*g[m] + vr**2*gpp[m] + vr*vc*(gp1 + gp2)[m]
        m &= zero_tau

        # k22
        m = m12 * m22
        K[m] = lc**2*g[m]
        m &= zero_tau

        # k33
        m = m13 * m23
        K[m] = bc**2*g[m] + br**2*gpp[m] + bc*br*(gp1 + gp2)[m]
        m &= zero_tau

        # k12
        m = m11 * m22
        K[m] = vc*lc*g[m] + vr*lc*gp2[m]
        m = m12 * m21
        K[m] = vc*lc*g[m] + vr*lc*gp1[m]

        # k13
        m = m11 * m23
        K[m] = vc*bc*g[m] + vr*br*gpp[m] + vc*br*gp1[m] + vr*bc*gp2[m]
        m = m13 * m21
        K[m] = vc*bc*g[m] + vr*br*gpp[m] + vc*br*gp2[m] + vr*bc*gp1[m]

        # k23
        m = m12 * m23
        K[m] = lc*bc*g[m] + lc*br*gp1[m]
        m = m13 * m22
        K[m] = lc*bc*g[m] + lc*br*gp2[m]

        return K

# %%
func = SimpleKernel(0.1)
kernel = RVKernel(func, 1.0, 1.0, 0.6, 0.3, 0.5)

# %%
#generate some correlated time series according to a kernel K
npts = 100
ndim = 3

time = np.linspace(0, 10, npts)
index = np.zeros(len(time))
t, l = np.zeros(0), np.zeros(0)
for i in range(ndim):
    t = np.concatenate((t,time))
    l = np.concatenate((l,index + i))

Kern = kernel.get_value(t[:, None] - t[None, :], l[:, None], l[None, :])
Kern[np.diag_indices(len(t))] += 0.1
y = np.random.multivariate_normal(np.zeros_like(t), Kern)

for i in range(ndim):
    line, = plt.plot(t[l==i], y[l==i])

# %% [markdown]
# ### Deep Learned Kernel, alternate

# %%
from gpflow.params import Parameterized
from gpflow import Param
from gpflow.kernels import RBF

def xavier(dim_in, dim_out):
    return np.random.randn(dim_in, dim_out)*(2./(dim_in+dim_out))**0.5

class NN(Parameterized):
    def __init__(self, dims):
        Parameterized.__init__(self)
        self.dims = dims
        for i, (dim_in, dim_out) in enumerate(zip(dims[:-1], dims[1:])):
            setattr(self, 'W_{}'.format(i), Param(xavier(dim_in, dim_out)))
            setattr(self, 'b_{}'.format(i), Param(np.zeros(dim_out)))

    def forward(self, X):
        if X is not None:
            for i in range(len(self.dims) - 1):
                W = getattr(self, 'W_{}'.format(i))
                b = getattr(self, 'b_{}'.format(i))
                X = tf.nn.tanh(tf.matmul(X, W) + b)
            return X

class NN_RBF(RBF):
    def __init__(self, nn, *args, **kw):
        RBF.__init__(self, *args, **kw)
        self.nn = nn
    
    def square_dist(self, X, X2):
        return RBF.square_dist(self, self.nn.forward(X), self.nn.forward(X2))

## Pristine Version ##
'''
def xavier(dim_in, dim_out):
    return np.random.randn(dim_in, dim_out)*(2./(dim_in+dim_out))**0.5

class NN(Parameterized):
    def __init__(self, dims):
        Parameterized.__init__(self)
        self.dims = dims
        for i, (dim_in, dim_out) in enumerate(zip(dims[:-1], dims[1:])):
            setattr(self, 'W_{}'.format(i), Param(xavier(dim_in, dim_out)))
            setattr(self, 'b_{}'.format(i), Param(np.zeros(dim_out)))

    def forward(self, X):
        if X is not None:
            for i in range(len(self.dims) - 1):
                W = getattr(self, 'W_{}'.format(i))
                b = getattr(self, 'b_{}'.format(i))
                X = tf.nn.tanh(tf.matmul(X, W) + b)
            return X

class NN_RBF(RBF):
    def __init__(self, nn, *args, **kw):
        RBF.__init__(self, *args, **kw)
        self.nn = nn
    
    def square_dist(self, X, X2):
        return RBF.square_dist(self, self.nn.forward(X), self.nn.forward(X2))
'''

# %%
#data - arrange this way like http://gpflow.readthedocs.io/en/latest/notebooks/coreg_demo.html
X = np.vstack((t,l)).T
Y = np.vstack((y,l)).T

# %%
coreg = gpflow.kernels.Coregion(input_dim, output_dim=ndim, rank=ndim, active_dims=[1])
lik = gpflow.likelihoods.SwitchedLikelihood([gpflow.likelihoods.StudentT()]*ndim)

input_dim = 1
# I think this goes input_dim, X*(hidden layers), output_dim
net = NN([input_dim, 20, 20, ndim])  # for 1D inputs and a ndim dimensional GP
kern = NN_RBF(net, input_dim) * coreg

m = gpflow.models.SVGP(X, Y, kern=kern, likelihood=lik, num_latent=1, Z=X[::3].copy())

#randomize coregionalization matrix W for best results
Wshape = m.kern.coregion.W.shape
m.kern.coregion.W = np.random.randn(Wshape[0], Wshape[1])

# %%
gpflow.train.ScipyOptimizer().minimize(m, maxiter=1000)
# Out:
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:95: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS EXCEEDS LIMIT'
#   Objective function value: 228.921774
#   Number of iterations: 1001
#   Number of functions evaluations: 1095

# %%
xtest = np.linspace(0, 10, npts)[:,None]
for i in range(ndim):
    line, = plt.plot(t[l==i], y[l==i], '.')
    mu, var = m.predict_f(np.hstack((xtest, i+np.zeros_like(xtest))))
    plt.plot(xtest, mu, color=line.get_color(), lw=2)
    mu, var = mu.reshape(npts,), var.reshape(npts,)
    plt.fill_between(xtest.reshape(npts,), mu-2*np.sqrt(var), mu+2*np.sqrt(var), color=line.get_color(), alpha=0.2)

# %%
print(m)
# Out:
# <Parameter name:SVGP/kern/nn_rbf/variance [trainable] shape:() transform:+ve prior:None>
# value: 0.10204634615599438
#
# <Parameter name:SVGP/kern/nn_rbf/lengthscales [trainable] shape:() transform:+ve prior:None>
# value: 0.12311657478796377
#
# <Parameter name:SVGP/kern/nn_rbf/nn/W_0 [trainable] shape:(1, 20) transform:(none) prior:None>
# value: [[ 0.61741774,  0.05825846,  0.0706283 , ...,  0.62262585,
#          -0.3615649 , -0.27377987]]
#
# <Parameter name:SVGP/kern/nn_rbf/nn/b_0 [trainable] shape:(20,) transform:(none) prior:None>
# value: [ 0.6170355 ,  0.16495859, -0.45327375, ...,  0.66742638,
#          0.51326873, -0.17899954]
#
# <Parameter name:SVGP/kern/nn_rbf/nn/W_1 [trainable] shape:(20, 20) transform:(none) prior:None>
# value: [[-0.38346173, -0.11977039,  0.03687077, ..., -0.5082208 ,
#          -0.3022521 , -0.04827139],
#         [ 0.11877662, -0.23728763,  0.1460291 , ..., -0.00649342,
#          -0.16306239, -0.13613534],
#         [ 0.03037467,  0.01880186, -0.23584128, ...,  0.00380855,
#          -0.2395952 , -0.4084443 ],
#         ...,
#         [-0.44482406, -0.58538978,  0.4923581 , ..., -0.47854593,
#          -0.1081081 ,  0.171871  ],
#         [ 0.13430051,  0.29670976,  0.15336293, ..., -0.07880369,
#           0.0166946 ,  0.28488336],
#         [ 0.12571177,  0.02586727,  0.1403235 , ...,  0.36869883,
#           0.18026872, -0.23147867]]
#
# <Parameter name:SVGP/kern/nn_rbf/nn/b_1 [trainable] shape:(20,) transform:(none) prior:None>
# value: [-0.33905032, -0.3168736 ,  0.44833043, ..., -0.48597791,
#         -0.59278432,  0.27379082]
#
# <Parameter name:SVGP/kern/nn_rbf/nn/W_2 [trainable] shape:(20, 3) transform:(none) prior:None>
# value: [[-0.12489824,  0.57845491, -0.67786141],
#         [-0.49355537,  0.48878583, -0.53602252],
#         [ 0.27096087, -0.3475639 ,  0.46185771],
#         ...,
#         [-0.24613506,  0.96178573, -0.60963347],
#         [ 0.22923514,  0.55831572, -0.10497187],
#         [-0.3090926 , -0.39490431,  0.27958154]]
#
# <Parameter name:SVGP/kern/nn_rbf/nn/b_2 [trainable] shape:(3,) transform:(none) prior:None>
# value: [-0.20478179, -1.02995439,  0.82169497]
#
# <Parameter name:SVGP/kern/coregion/W [trainable] shape:(3, 3) transform:(none) prior:None>
# value: [[ -2.79166103e-05,   6.91192977e-02,  -2.70726873e-02],
#         [  2.29810465e-01,   5.66169176e+00,  -9.36337668e-02],
#         [ -3.34804138e-01,   6.26898989e-01,   6.39083399e-01]]
#
# <Parameter name:SVGP/kern/coregion/kappa [trainable] shape:(3,) transform:+ve prior:None>
# value: [ 0.01199596,  1.21116888,  0.24856266]
#
# <Parameter name:SVGP/likelihood/likelihood_list/item2/scale [trainable] shape:() transform:+ve prior:None>
# value: 0.3572713714194586
#
# <Parameter name:SVGP/likelihood/likelihood_list/item2/scale [trainable] shape:() transform:+ve prior:None>
# value: 0.3572713714194586
#
# <Parameter name:SVGP/likelihood/likelihood_list/item2/scale [trainable] shape:() transform:+ve prior:None>
# value: 0.3572713714194586
#
# <Parameter name:SVGP/Z [trainable] shape:(100, 2) transform:(none) prior:None>
# value: [[ 0.29846044,  0.        ],
#         [ 0.89108443,  0.        ],
#         [ 1.20514427,  0.        ],
#         ...,
#         [ 9.19177366,  2.        ],
#         [ 9.4949155 ,  2.        ],
#         [ 9.79798419,  2.        ]]
#
# <Parameter name:SVGP/q_mu [trainable] shape:(100, 1) transform:(none) prior:None>
# value: [[-0.0751448 ],
#         [ 0.97939839],
#         [ 0.68449202],
#         ...,
#         [ 0.01270645],
#         [ 0.01336497],
#         [ 0.00636061]]
#
# <Parameter name:SVGP/q_sqrt [trainable] shape:(100, 100, 1) transform:LoTri->vec prior:None>
# value: [[[ -7.05418172e-01],
#          [  0.00000000e+00],
#          [  0.00000000e+00],
#          ...,
#          [  0.00000000e+00],
#          [  0.00000000e+00],
#          [  0.00000000e+00]],
#
#         [[ -4.26518597e-02],
#          [  8.19462473e-01],
#          [  0.00000000e+00],
#          ...,
#          [  0.00000000e+00],
#          [  0.00000000e+00],
#          [  0.00000000e+00]],
#
#         [[ -3.22129044e-02],
#          [ -1.80680364e-02],
#          [  8.98327718e-01],
#          ...,
#          [  0.00000000e+00],
#          [  0.00000000e+00],
#          [  0.00000000e+00]],
#
#         ...,
#         [[  1.48231258e-04],
#          [  3.14221896e-04],
#          [ -8.14130840e-05],
#          ...,
#          [  9.93548282e-01],
#          [  0.00000000e+00],
#          [  0.00000000e+00]],
#
#         [[  1.69156642e-04],
#          [  2.31671532e-04],
#          [ -7.10776373e-05],
#          ...,
#          [ -4.02630127e-03],
#          [  9.97903888e-01],
#          [  0.00000000e+00]],
#
#         [[  5.13061727e-05],
#          [  7.30186870e-05],
#          [ -7.57971443e-06],
#          ...,
#          [ -1.40370530e-03],
#          [ -8.32438130e-04],
#          [  9.99716778e-01]]]

# %% [markdown]
# ### Deep Learned Kernel Code

# %%
#https://blog.keras.io/keras-as-a-simplified-interface-to-tensorflow-tutorial.html
def nn(npts):
    sess = tf.Session()
    K.set_session(sess)
    
    img = tf.placeholder(tf.float32, shape=(None,1))
    x = Dense(128, activation='relu')(img)
    x = Dense(128, activation='relu')(x)
    out = Dense(1, activation='relu')(x)
    return out, sess

# %%
#keras/tf part
h, sess = nn(npts)
h = tf.cast(h, gpflow.settings.tf_float)
init_op = tf.global_variables_initializer()
sess.run(init_op)

# %%
#gpflow part
with gpflow.defer_build():
    kernel = gpflow.kernels.RBF(npts)
    #lik = gpflow.likelihoods.MultiClass(ndim)
    lik = gpflow.likelihoods.SwitchedLikelihood([gpflow.likelihoods.StudentT()]*ndim)
    gp_model = gpflow.models.SVGP(h, Y, kernel, lik, np.ones(npts, gpflow.settings.np_float),
                                  num_latent=1, minibatch_size=None, num_data=npts)
# ^ so we say minibatch size is None to make sure we get DataHolder rather than minibatch data holder, which
# does not allow us to give in tensors. But we will handle all our minibatching outside.

# %%
gp_model.compile(sess)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, require_shape_fn)
#     653           graph_def_version, node_def_str, input_shapes, input_tensors,
# --> 654           input_tensors_as_shapes, status)
#     655   except errors.InvalidArgumentError as err:
#
# /storage/work/ajs725/conda/install/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# InvalidArgumentError: Index out of range using input dim 1; input has only 1 dims for '9/SVGP/conditional/strided_slice_2' (op: 'StridedSlice') with input shapes: [100], [2], [2], [2] and with computed input tensors: input[3] = <1 1>.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e60df635629f> in <module>()
# ----> 1 gp_model.compile(sess)
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/gpflow/core/node.py in compile(self, session)
#      56         if self.is_built_coherence(session.graph) is Build.NO:
#      57             with session.graph.as_default():
# ---> 58                 self.build()
#      59         self.initialize(session, force=True)
#      60
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/gpflow/core/node.py in build(self)
#     128             name = self.hidden_name if self.parent is self else self.name
#     129             with tf.name_scope(name):
# --> 130                 self._build()
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/gpflow/models/model.py in _build(self)
#      79     def _build(self):
#      80         super(Model, self)._build()
# ---> 81         likelihood = self._build_likelihood()
#      82         prior = self.prior_tensor
#      83         objective = self._build_objective(likelihood, prior)
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/gpflow/decors.py in tensor_mode_wrapper(obj, *args, **kwargs)
#      58         prev_value = _params_as_tensors_enter(obj, True)
#      59         try:
# ---> 60             result = method(obj, *args, **kwargs)
#      61         finally:
#      62             _params_as_tensors_exit(obj, prev_value)
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/gpflow/models/svgp.py in _build_likelihood(self)
#     114
#     115         # Get conditionals
# --> 116         fmean, fvar = self._build_predict(self.X, full_cov=False)
#     117
#     118         # Get variational expectations.
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/gpflow/decors.py in tensor_mode_wrapper(obj, *args, **kwargs)
#      58         prev_value = _params_as_tensors_enter(obj, True)
#      59         try:
# ---> 60             result = method(obj, *args, **kwargs)
#      61         finally:
#      62             _params_as_tensors_exit(obj, prev_value)
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/gpflow/models/svgp.py in _build_predict(self, Xnew, full_cov)
#     127     def _build_predict(self, Xnew, full_cov=False):
#     128         mu, var = conditionals.conditional(Xnew, self.Z, self.kern, self.q_mu,
# --> 129                                            q_sqrt=self.q_sqrt, full_cov=full_cov, whiten=self.whiten)
#     130         return mu + self.mean_function(Xnew), var
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/gpflow/decors.py in runnable(*args, **kwargs)
#      40             scope_name = name if name is not None else method.__name__
#      41             with tf.name_scope(scope_name):
# ---> 42                 return method(*args, **kwargs)
#      43         return runnable
#      44     return name_scope_wrapper
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/gpflow/conditionals.py in conditional(Xnew, X, kern, f, full_cov, q_sqrt, whiten)
#      59     num_data = tf.shape(X)[0]  # M
#      60     num_func = tf.shape(f)[1]  # K
# ---> 61     Kmn = kern.K(X, Xnew)
#      62     Kmm = kern.K(X) + tf.eye(num_data, dtype=settings.tf_float) * settings.numerics.jitter_level
#      63     Lm = tf.cholesky(Kmm)
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/gpflow/decors.py in tensor_mode_wrapper(obj, *args, **kwargs)
#      58         prev_value = _params_as_tensors_enter(obj, True)
#      59         try:
# ---> 60             result = method(obj, *args, **kwargs)
#      61         finally:
#      62             _params_as_tensors_exit(obj, prev_value)
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/gpflow/kernels.py in K(self, X, X2, presliced)
#     407     def K(self, X, X2=None, presliced=False):
#     408         if not presliced:
# --> 409             X, X2 = self._slice(X, X2)
#     410         return self.variance * tf.exp(-self.square_dist(X, X2) / 2)
#     411
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/gpflow/kernels.py in _slice(self, X, X2)
#     240         """
#     241         if isinstance(self.active_dims, slice):
# --> 242             X = X[:, self.active_dims]
#     243             if X2 is not None:
#     244                 X2 = X2[:, self.active_dims]
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in _SliceHelper(tensor, slice_spec, var)
#     507         ellipsis_mask=ellipsis_mask,
#     508         var=var,
# --> 509         name=name)
#     510
#     511
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#     675       ellipsis_mask=ellipsis_mask,
#     676       new_axis_mask=new_axis_mask,
# --> 677       shrink_axis_mask=shrink_axis_mask)
#     678
#     679   parent_name = name
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/tensorflow/python/ops/gen_array_ops.py in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#    3742                                 ellipsis_mask=ellipsis_mask,
#    3743                                 new_axis_mask=new_axis_mask,
# -> 3744                                 shrink_axis_mask=shrink_axis_mask, name=name)
#    3745   return result
#    3746
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     765         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     766                          input_types=input_types, attrs=attr_protos,
# --> 767                          op_def=op_def)
#     768         if output_structure:
#     769           outputs = op.outputs
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2630                     original_op=self._default_original_op, op_def=op_def)
#    2631     if compute_shapes:
# -> 2632       set_shapes_for_outputs(ret)
#    2633     self._add_op(ret)
#    2634     self._record_op_seen_by_control_dependencies(ret)
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in set_shapes_for_outputs(op)
#    1909       shape_func = _call_cpp_shape_fn_and_require_op
#    1910
# -> 1911   shapes = shape_func(op)
#    1912   if shapes is None:
#    1913     raise RuntimeError(
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in call_with_requiring(op)
#    1859
#    1860   def call_with_requiring(op):
# -> 1861     return call_cpp_shape_fn(op, require_shape_fn=True)
#    1862
#    1863   _call_cpp_shape_fn_and_require_op = call_with_requiring
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in call_cpp_shape_fn(op, require_shape_fn)
#     593     res = _call_cpp_shape_fn_impl(op, input_tensors_needed,
#     594                                   input_tensors_as_shapes_needed,
# --> 595                                   require_shape_fn)
#     596     if not isinstance(res, dict):
#     597       # Handles the case where _call_cpp_shape_fn_impl calls unknown_shape(op).
#
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, require_shape_fn)
#     657       missing_shape_fn = True
#     658     else:
# --> 659       raise ValueError(err.message)
#     660
#     661   if missing_shape_fn:
#
# ValueError: Index out of range using input dim 1; input has only 1 dims for '9/SVGP/conditional/strided_slice_2' (op: 'StridedSlice') with input shapes: [100], [2], [2], [2] and with computed input tensors: input[3] = <1 1>.

# %% [markdown]
# ### Build model, format data arrays, train (works)

# %%
#arrange data
X = np.vstack((t,l)).T
Y = np.vstack((y,l)).T

#set up coregionalized kernel
input_dim = 1
coreg = gpflow.kernels.Coregion(input_dim, output_dim=ndim, rank=ndim, active_dims=[1])
k = gpflow.kernels.Exponential(1)
kern = k * coreg
lik = gpflow.likelihoods.SwitchedLikelihood([gpflow.likelihoods.StudentT()]*ndim)
        
m = gpflow.models.SVGP(X, Y, kern=kern, likelihood=lik, num_latent=1, Z=X[::3].copy())

# %%
#optimize
gpflow.train.ScipyOptimizer().minimize(m, maxiter=500)
# Out:
# /storage/work/ajs725/conda/install/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:95: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS EXCEEDS LIMIT'
#   Objective function value: 223.357179
#   Number of iterations: 501
#   Number of functions evaluations: 577

# %%
xtest = np.linspace(0, 10, npts)[:,None]
for i in range(ndim):
    line, = plt.plot(t[l==i], y[l==i], '.')
    mu, var = m.predict_f(np.hstack((xtest, i+np.zeros_like(xtest))))
    plt.plot(xtest, mu, color=line.get_color(), lw=2)
    mu, var = mu.reshape(npts,), var.reshape(npts,)
    plt.fill_between(xtest.reshape(npts,), mu-2*np.sqrt(var), mu+2*np.sqrt(var), color=line.get_color(), alpha=0.2)

# %%
#print(m)

# %% [markdown]
# ### Part 3 - Try and Model this with a NN kernel and/or adding multiple GPs together
# - https://github.com/GPflow/GPflow/issues/505 - end-to-end NN kernel with GP on top
# - https://github.com/GPflow/GPflow/issues/297#issuecomment-267765077 - combining GPs
# - https://gist.github.com/john-bradshaw/11bbf17dbca013d9fc3886a7bfe46840 - end to end training of NN + GP

# %%
#this is how to make d(t) = a_1 X_1(t) + a_2 X_2(t)
from functools import reduce
import tensorflow as tf
class ProductModel(gpflow.models.Model):
    def __init__(self, models):
        gpflow.model.Model.__init__(self)
        self.models = gpflow.param.ParamList(models)

    def build_likelihood(self):
        return reduce(tf.add, (m.build_likelihood() for m in self.models))
    
#This is how to make a NN kernel
from gpflow.params import Parameterized
from gpflow.kernels import RBF
def xavier(dim_in, dim_out):
    return np.random.randn(dim_in, dim_out)*(2./(dim_in+dim_out))**0.5

class NN(Parameterized):
    def __init__(self, dims):
        Parameterized.__init__(self)
        self.dims = dims
        for i, (dim_in, dim_out) in enumerate(zip(dims[:-1], dims[1:])):
            setattr(self, 'W_{}'.format(i), param.Param(xavier(dim_in, dim_out)))
            setattr(self, 'b_{}'.format(i), param.Param(np.zeros(dim_out)))

    def forward(self, X):
        if X is not None:
            for i in range(len(self.dims) - 1):
                W = getattr(self, 'W_{}'.format(i))
                b = getattr(self, 'b_{}'.format(i))
                X = tf.nn.tanh(tf.matmul(X, W) + b)
            return X

class NN_RBF(RBF):
    def __init__(self, nn, *args, **kw):
        RBF.__init__(self, *args, **kw)
        self.nn = nn
    
    def square_dist(self, X, X2):
        return RBF.square_dist(self, self.nn.forward(X), self.nn.forward(X2))

# %%
#arrange data
X = np.vstack((t,l)).T
Y = np.vstack((y,l)).T

#set up coregionalized kernel
input_dim = 1
coreg = gpflow.kernels.Coregion(input_dim, output_dim=ndim, rank=1, active_dims=[1])
lik = gpflow.likelihoods.SwitchedLikelihood([gpflow.likelihoods.StudentT()]*ndim)

#set up model 1
net = NN([1, npts, 1])  # for 1D inputs and a ndim GP
k1 = NN_RBF(net, 1) 
m = gpflow.svgp.SVGP(X, Y, kern=k1, likelihood=lik, num_latent=1,Z=X[::3].copy())
#m1 = gpflow.svgp.SVGP(X, Y, kern=k1, likelihood=lik, num_latent=1,Z=X[::3].copy())

# #set up model 2
# k2 = gpflow.kernels.Matern32(1) * coreg
# m2 = gpflow.svgp.SVGP(X, Y, kern=k2, likelihood=lik, num_latent=1,Z=X[::3].copy())

# m = ProductModel([m1,m2])
# Out:
# [1, 100, 1]

# %%
m.optimize(maxiter=500)
# Out:
#       fun: 375.87803260250251
#  hess_inv: <5656x5656 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ -5.29589716e+00,   0.00000000e+00,   8.02118722e-01, ...,
#         -4.28253146e-07,   8.01897423e-07,   1.88566277e-06])
#   message: 'STOP: TOTAL NO. of ITERATIONS EXCEEDS LIMIT'
#      nfev: 636
#       nit: 501
#    status: 1
#   success: False
#         x: array([  1.18480668e-01,   0.00000000e+00,   1.90609366e-01, ...,
#         -2.72002392e-07,  -8.43521324e-07,   9.99999067e-01])

# %%
xtest = np.linspace(0, 10, npts)[:,None]
for i in np.arange(ndim):
    line, = plt.plot(t[l==i], y[l==i], '.')
    mu, var = m.predict_f(np.hstack((xtest, i+np.zeros_like(xtest))))
    plt.plot(xtest, mu, color=line.get_color(), lw=2)
    mu, var = mu.reshape(npts,), var.reshape(npts,)
    plt.fill_between(xtest.reshape(npts,), mu-2*np.sqrt(var), mu+2*np.sqrt(var), color=line.get_color(), alpha=0.2)

# %% [markdown]
# ### Scratch

# %%
from gpflow.param import Parameterized

def xavier(dim_in, dim_out):
    return np.random.randn(dim_in, dim_out)*(2./(dim_in+dim_out))**0.5

class NN(Parameterized):
    def __init__(self, dims):
        Parameterized.__init__(self)
        self.dims = dims
        for i, (dim_in, dim_out) in enumerate(zip(dims[:-1], dims[1:])):
            setattr(self, 'W_{}'.format(i), Param(xavier(dim_in, dim_out)))
            setattr(self, 'b_{}'.format(i), Param(np.zeros(dim_out)))

    def forward(self, X):
        if X is not None:
            for i in range(len(self.dims) - 1):
                W = getattr(self, 'W_{}'.format(i))
                b = getattr(self, 'b_{}'.format(i))
                X = tf.nn.tanh(tf.matmul(X, W) + b)
            return X
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-87b2e602e043> in <module>()
# ----> 1 from gpflow.param import Parameterized
#       2
#       3 def xavier(dim_in, dim_out):
#       4     return np.random.randn(dim_in, dim_out)*(2./(dim_in+dim_out))**0.5
#       5
#
# ModuleNotFoundError: No module named 'gpflow.param'

# %%
#rearrange data into (nsteps,ndim)
time = np.array((t[l==1],t[l==2],t[l==3])).T
#time = t[l==1]
data = np.array((y[l==1],y[l==2],y[l==3])).T
#time = t[l==1]
#data = y[l==1]

train_frac, batch_size = 0.8, 10
split = int(train_frac*len(time))
#X_train, y_train = time[0:split], data[0:split]
#X_test, y_test = time[split:], data[split]
X_train, y_train = time[0:split,:], data[0:split,:]
X_test, y_test = time[split:,:], data[split,:]

data_ = {
    'train': (X_train, y_train),
    'test': (X_test, y_test)
}

# data_ = {
#     'train': (X_train.reshape(1,-1), y_train.reshape(1,-1)),
#     'test': (X_test.reshape(1,-1), y_test.reshape(1,-1))
# }

input_shape = X_train.shape
print input_shape
# Out:
# (80, 3)

# %%
gp_hypers = {'lik': -2.0, 'cov': [[-0.7], [0.0]]}

# Build the model
inputs = Input(shape=input_shape)
hidden = Dense(input_shape[0], activation='relu')(inputs)
hidden = Dense(input_shape[0], activation='relu')(hidden)
#rnn = SimpleRNN(32)(inputs)
gp = GP(gp_hypers,
        batch_size=batch_size,
        nb_train_samples=len(X_train))
outputs = [gp(hidden)]
#outputs = [gp(rnn)]  # 2 GPs assigned to each output dimension
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
loss = [gen_gp_loss(gp) for gp in model.output_layers]
model.compile(optimizer=Adam(1e-2), loss=loss)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-47-23d232b5eb01> in <module>()
#       9         batch_size=batch_size,
#      10         nb_train_samples=len(X_train))
# ---> 11 outputs = [gp(hidden)]
#      12 #outputs = [gp(rnn)]  # 2 GPs assigned to each output dimension
#      13 model = Model(inputs=inputs, outputs=outputs)
#
# /storage/home/ajs725/tf-ml/lib/python2.7/site-packages/keras/engine/topology.pyc in __call__(self, inputs, **kwargs)
#     573                                          '`layer.build(batch_input_shape)`')
#     574                 if len(input_shapes) == 1:
# --> 575                     self.build(input_shapes[0])
#     576                 else:
#     577                     self.build(input_shapes)
#
# /storage/home/ajs725/kgp/kgp/layers.pyc in build(self, input_shape)
#     137                 for weight shape computations.
#     138         """
# --> 139         assert len(input_shape) == 2
#     140         input_dim = input_shape[-1]
#     141         self.input_spec = InputSpec(dtype=K.floatx(), shape=(None, input_dim))
#
# AssertionError:

# %%
epochs = 5
history = train(model, data_, callbacks=[], gp_n_iter=5,
                epochs=epochs, batch_size=batch_size, verbose=1)
# Out:
# Training...
# error: `ME' undefined near line 81 column 7
# error: called from:
# error:   /storage/home/ajs725/tf-ml/lib/python2.7/site-packages/oct2py/_pyeval.m at line 81, column 7
# ---------------------------------------------------------------------------
# Oct2PyError                               Traceback (most recent call last)
# <ipython-input-43-92815edc26a3> in <module>()
#       1 epochs = 5
#       2 history = train(model, data_, callbacks=[], gp_n_iter=5,
# ----> 3                 epochs=epochs, batch_size=batch_size, verbose=1)
#
# /storage/home/ajs725/kgp/kgp/utils/experiment.pyc in train(model, data, epochs, batch_size, callbacks, checkpoint, checkpoint_monitor, verbose, **fit_kwargs)
#      65                         batch_size=batch_size, epochs=epochs,
#      66                         callbacks=callbacks, verbose=verbose,
# ---> 67                         **fit_kwargs)
#      68
#      69     if verbose:
#
# /storage/home/ajs725/kgp/kgp/models.pyc in fit(self, X, Y, batch_size, epochs, gp_n_iter, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     126             shuffle=shuffle,
#     127             initial_epoch=initial_epoch,
# --> 128             **kwargs)
#     129
#     130     def finetune(self, X, Y, batch_size=32, gp_n_iter=1, verbose=1):
#
# /storage/home/ajs725/tf-ml/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1596                               initial_epoch=initial_epoch,
#    1597                               steps_per_epoch=steps_per_epoch,
# -> 1598                               validation_steps=validation_steps)
#    1599
#    1600     def evaluate(self, x, y,
#
# /storage/home/ajs725/kgp/kgp/tweaks.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     110
#     111     for epoch in range(initial_epoch, epochs):
# --> 112         callbacks.on_epoch_begin(epoch)
#     113         epoch_logs = {}
#     114         if steps_per_epoch is not None:
#
# /storage/home/ajs725/tf-ml/lib/python2.7/site-packages/keras/callbacks.pyc in on_epoch_begin(self, epoch, logs)
#      61         logs = logs or {}
#      62         for callback in self.callbacks:
# ---> 63             callback.on_epoch_begin(epoch, logs)
#      64         self._delta_t_batch = 0.
#      65         self._delta_ts_batch_begin = deque([], maxlen=self.queue_length)
#
# /storage/home/ajs725/kgp/kgp/callbacks.pyc in on_epoch_begin(self, epoch, logs)
#      65
#      66             # Compute MSE and NLML
# ---> 67             nlml, preds = gp.backend.eval_predict(h)
#      68             gp.nlml, gp.mse = nlml, MSE(y, preds)
#      69         logs['gp_update_elapsed'] = np.mean(gp_update_elapsed)
#
# /storage/home/ajs725/kgp/kgp/backend/gpml.pyc in eval_predict(self, X, X_tr, y_tr, verbose)
#     219             self.eng.eval(_gp_evaluate.format(**self.config), verbose=verbose)
#     220             self.eng.eval(_gp_predict.format(**self.config), verbose=verbose)
# --> 221         return self.eng.pull('nlZ'), self.eng.pull('ymu')
#
# /storage/home/ajs725/kgp/kgp/backend/engines.pyc in pull(self, name)
#      90
#      91     def pull(self, name):
# ---> 92         var = self._eng.pull(name)
#      93         if type(var) is self._struct:
#      94             var = dict(var)
#
# /storage/home/ajs725/tf-ml/lib/python2.7/site-packages/oct2py/core.pyc in pull(self, var, timeout, verbose)
#     178         outputs = []
#     179         for name in var:
# --> 180             exist = self._exist(name)
#     181             if exist == 1:
#     182                 outputs.append(self.feval('evalin', 'base', name,
#
# /storage/home/ajs725/tf-ml/lib/python2.7/site-packages/oct2py/core.pyc in _exist(self, name)
#     667         if exist == 0:
#     668             msg = 'Value "%s" does not exist in Octave workspace'
# --> 669             raise Oct2PyError(msg % name)
#     670         return exist
#     671
#
# Oct2PyError: Value "nlZ" does not exist in Octave workspace

# %%
#https://github.com/alshedivat/keras-gp/blob/master/examples/msgp_mlp_kin40k.py
def assemble_mlp(input_shape, output_shape, batch_size, nb_train_samples):
    inputs = Input(shape=input_shape)
    hidden = Dense(10, activation='relu')(inputs)
    hidden = Dense(10, activation='relu')(hidden)
    #hidden = Dense(input_shape, activation='relu')(hidden)
    gp = GP(hyp={
                'lik': np.log(0.3),
                'mean': [],
                'cov': [[0.5], [1.0]],
            },
            inf='infGrid', dlik='dlikGrid',
            opt={'cg_maxit': 2000, 'cg_tol': 1e-6},
            mean='meanZero', cov='covSEiso',
            update_grid=1,
            grid_kwargs={'eq': 1, 'k': 70.},
            batch_size=batch_size,
            nb_train_samples=nb_train_samples)
    outputs = []
    for i in range(output_shape[1]):
        outputs.append()
    return Model(inputs=inputs, outputs=outputs)

# %%
model = assemble_mlp(input_shape,output_shape,batch_size,split)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-168-5934ee834c54> in <module>()
# ----> 1 model = assemble_mlp(input_shape,output_shape,batch_size,split)
#
# <ipython-input-167-aff4cc2a37ed> in assemble_mlp(input_shape, output_shape, batch_size, nb_train_samples)
#      17     outputs = []
#      18     for i in range(3):
# ---> 19         outputs.append(gp(hidden))
#      20     return Model(inputs=inputs, outputs=outputs)
#
# /storage/home/ajs725/tf-ml/lib/python2.7/site-packages/keras/engine/topology.pyc in __call__(self, inputs, **kwargs)
#     573                                          '`layer.build(batch_input_shape)`')
#     574                 if len(input_shapes) == 1:
# --> 575                     self.build(input_shapes[0])
#     576                 else:
#     577                     self.build(input_shapes)
#
# /storage/home/ajs725/kgp/kgp/layers.pyc in build(self, input_shape)
#     137                 for weight shape computations.
#     138         """
# --> 139         assert len(input_shape) == 2
#     140         input_dim = input_shape[-1]
#     141         self.input_spec = InputSpec(dtype=K.floatx(), shape=(None, input_dim))
#
# AssertionError:

# %%
loss = [gen_gp_loss(gp) for gp in model.output_layers]
model.compile(optimizer=Adam(1e-4), loss=loss)

# %%
epochs = 5
history = train(model, data_, callbacks=[], gp_n_iter=5,
                epochs=epochs, batch_size=batch_size, verbose=1)
# Out:
# Training...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-92815edc26a3> in <module>()
#       1 epochs = 5
#       2 history = train(model, data_, callbacks=[], gp_n_iter=5,
# ----> 3                 epochs=epochs, batch_size=batch_size, verbose=1)
#
# /storage/home/ajs725/kgp/kgp/utils/experiment.py in train(model, data, epochs, batch_size, callbacks, checkpoint, checkpoint_monitor, verbose, **fit_kwargs)
#      65                         batch_size=batch_size, epochs=epochs,
#      66                         callbacks=callbacks, verbose=verbose,
# ---> 67                         **fit_kwargs)
#      68
#      69     if verbose:
#
# /storage/home/ajs725/kgp/kgp/models.pyc in fit(self, X, Y, batch_size, epochs, gp_n_iter, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     100             class_weight=None,
#     101             check_batch_axis=False,
# --> 102             batch_size=batch_size)
#     103         if validation_data is not None:
#     104             X_val, Y_val, _ = self._standardize_user_data(
#
# /storage/home/ajs725/tf-ml/lib/python2.7/site-packages/keras/engine/training.pyc in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1376                                     self._feed_input_shapes,
#    1377                                     check_batch_axis=False,
# -> 1378                                     exception_prefix='input')
#    1379         y = _standardize_input_data(y, self._feed_output_names,
#    1380                                     output_shapes,
#
# /storage/home/ajs725/tf-ml/lib/python2.7/site-packages/keras/engine/training.pyc in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     142                             ' to have shape ' + str(shapes[i]) +
#     143                             ' but got array with shape ' +
# --> 144                             str(array.shape))
#     145     return arrays
#     146
#
# ValueError: Error when checking input: expected input_16 to have shape (None, 80) but got array with shape (80, 1)

# %% [markdown]
# ### Scratch

# %%
#generate data from a GP with a given kernel, but these are not necessarily correlated timeseries, just draws from 
#a GP with a specified kernel.

# %%
dataset_path = ''
dataa = np.load(dataset_path)

# %%
input_shape = (10, 2)  # 10 time steps, 2 dimensions
batch_size = 32
nb_train_samples = 512
gp_hypers = {'lik': -2.0, 'cov': [[-0.7], [0.0]]}

inputs = Input(shape=input_shape)
rnn = SimpleRNN(32)(inputs)
gp = GP(gp_hypers,
        batch_size=batch_size,
        nb_train_samples=nb_train_samples)
outputs = [gp(rnn)]
model = Model(inputs=inputs, outputs=outputs)
# Out:
# GP configuration:
# {'cov': '{@covSEiso}',
#  'dcov': '@dcovSEiso',
#  'dlik': '@(varargin) dlikExact(varargin{:}, opt)',
#  'inf': '{@(varargin) infExact(varargin{:}, opt)}',
#  'lik': '{@likGauss}',
#  'mean': '{@meanZero}'}

# %%
outputs[0]
# Out:
# <tf.Tensor 'gp_1/Identity:0' shape=(?, 32) dtype=float32>

# %%
import tensorflow as tf
sess = tf.Session()
with sess.as_default():
    gp(rnn).eval()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-49-e943626699c7> in <module>()
#       2 sess = tf.Session()
#       3 with sess.as_default():
# ----> 4     gp(rnn).eval()
#
# /gpfs/group/ebf11/default/sw/python-2.7.11-tf-1.0.0/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in eval(self, feed_dict, session)
#     565
#     566     """
# --> 567     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     568
#     569
#
# /gpfs/group/ebf11/default/sw/python-2.7.11-tf-1.0.0/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in _eval_using_default_session(tensors, feed_dict, graph, session)
#    3737                        "the tensor's graph is different from the session's "
#    3738                        "graph.")
# -> 3739   return session.run(tensors, feed_dict)
#    3740
#    3741
#
# /gpfs/group/ebf11/default/sw/python-2.7.11-tf-1.0.0/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     767     try:
#     768       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 769                          run_metadata_ptr)
#     770       if run_metadata:
#     771         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /gpfs/group/ebf11/default/sw/python-2.7.11-tf-1.0.0/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     965     if final_fetches or final_targets:
#     966       results = self._do_run(handle, final_targets, final_fetches,
# --> 967                              feed_dict_string, options, run_metadata)
#     968     else:
#     969       results = []
#
# /gpfs/group/ebf11/default/sw/python-2.7.11-tf-1.0.0/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1015     if handle is None:
#    1016       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1017                            target_list, options, run_metadata)
#    1018     else:
#    1019       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /gpfs/group/ebf11/default/sw/python-2.7.11-tf-1.0.0/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1035         except KeyError:
#    1036           pass
# -> 1037       raise type(e)(node_def, op, message)
#    1038
#    1039   def _extend_graph(self):
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'input_1' with dtype float
# 	 [[Node: input_1 = Placeholder[dtype=DT_FLOAT, shape=[], _device="/job:localhost/replica:0/task:0/cpu:0"]()]]
#
# Caused by op u'input_1', defined at:
#   File "/gpfs/group/ebf11/default/sw/python-2.7.11-tf-1.0.0/lib/python2.7/runpy.py", line 162, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/gpfs/group/ebf11/default/sw/python-2.7.11-tf-1.0.0/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-36-bc67349297ba>", line 6, in <module>
#     inputs = Input(shape=input_shape)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/keras/engine/topology.py", line 1436, in Input
#     input_tensor=tensor)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/keras/legacy/interfaces.py", line 87, in wrapper
#     return func(*args, **kwargs)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/keras/engine/topology.py", line 1347, in __init__
#     name=self.name)
#   File "/storage/home/ajs725/tf-ml/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py", line 442, in placeholder
#     x = tf.placeholder(dtype, shape=shape, name=name)
#   File "/gpfs/group/ebf11/default/sw/python-2.7.11-tf-1.0.0/lib/python2.7/site-packages/tensorflow/python/ops/array_ops.py", line 1505, in placeholder
#     name=name)
#   File "/gpfs/group/ebf11/default/sw/python-2.7.11-tf-1.0.0/lib/python2.7/site-packages/tensorflow/python/ops/gen_array_ops.py", line 2148, in _placeholder
#     name=name)
#   File "/gpfs/group/ebf11/default/sw/python-2.7.11-tf-1.0.0/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 768, in apply_op
#     op_def=op_def)
#   File "/gpfs/group/ebf11/default/sw/python-2.7.11-tf-1.0.0/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2334, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/gpfs/group/ebf11/default/sw/python-2.7.11-tf-1.0.0/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1226, in __init__
#     self._traceback = _extract_stack()
#
# InvalidArgumentError (see above for traceback): You must feed a value for placeholder tensor 'input_1' with dtype float
# 	 [[Node: input_1 = Placeholder[dtype=DT_FLOAT, shape=[], _device="/job:localhost/replica:0/task:0/cpu:0"]()]]
